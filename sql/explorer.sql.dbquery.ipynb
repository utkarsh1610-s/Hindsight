-- %%
SELECT ddate, value, known_from_ts, known_to_ts,
       revision_seq, change_class, round(pct_change * 100, 2) AS pct
FROM hindsight_dev.gold.fact_fundamental_pit
WHERE cik = 732717
  AND canonical_tag = 'REVENUE'
  AND qtrs = 4
ORDER BY ddate, known_from_ts;
