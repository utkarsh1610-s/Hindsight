-- %%
SELECT rebalance_dt,
       pct_decile_moved,
       pct_top_decile_turnover,
       pct_any_input_revised
FROM hindsight_dev.gold.agg_bias_by_quarter
WHERE rebalance_dt < '2024-06-30'
ORDER BY rebalance_dt;
